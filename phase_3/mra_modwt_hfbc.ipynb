# %%
import sys

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd



matplotlib.rcParams['figure.figsize'] = (16, 3)
sys.path.append("../wavelet_functions")
from dan_wavelets import dwt, idwt, modwt, imodwt, mra

# %%
bc = pd.read_csv("../datasets/hfbc_returns_1D.csv", header=None, index_col=0)
bc.rename(columns={
    bc.columns[0]: "returns"
}, inplace=True)

# %%
la8 = pd.read_csv("../datasets/la8.csv", index_col=0)

# %%
mra(bc.returns, 4, la8.h, la8.g, 8)
